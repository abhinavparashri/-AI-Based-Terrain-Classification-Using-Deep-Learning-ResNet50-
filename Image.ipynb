# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from PIL import Image

# Load pretrained ResNet50 model
model = ResNet50(weights="imagenet")

# Nature categories with keywords
nature_keywords = {
    "Rocky": ["rock", "mountain", "cliff", "alp", "valley", "ridge"],
    "Water": ["sea", "ocean", "lake", "river", "lakeside", "waterfall"],
    "Forest": ["forest", "wood", "tree", "rainforest", "pine"],
    "Grassland": ["meadow", "field", "pasture", "prairie", "park", "lawn"],
    "Sandy": ["sand", "beach", "sandbar", "seashore"],
    "Desert": ["desert", "dune"],
    "Snow": ["snow", "ice", "glacier"],
    "Urban": ["building", "street", "city", "tower", "skyscraper"],
    "Landscape": ["valley", "volcano", "plateau", "canyon"]
}

def detect_nature(image_path):
    try:
        # Load image
        img = Image.open(image_path).convert("RGB")

        # Display image
        plt.imshow(img)
        plt.axis("off")
        plt.title("Input Image")
        plt.show()

        # Resize for model
        img = img.resize((224, 224))
        img_array = np.array(img)
        img_array = np.expand_dims(img_array, axis=0)
        img_array = preprocess_input(img_array)

        # Predict objects
        preds = model.predict(img_array, verbose=0)
        results = decode_predictions(preds, top=5)[0]

        print("\nTop-5 Predictions:\n")
        labels = []
        for obj in results:
            label = obj[1].lower()
            confidence = obj[2] * 100
            labels.append(label)
            print(f"{label} : {confidence:.2f}%")

        print("\nDetected Image Nature:\n")
        detected_nature = set()

        for nature, keywords in nature_keywords.items():
            for label in labels:
                if any(key in label for key in keywords):
                    detected_nature.add(nature)

        if detected_nature:
            print(", ".join(detected_nature))
        else:
            print("Nature type not clearly detected")

    except FileNotFoundError:
        print("Error: Image file not found. Check the image path.")

# Run with your image file
detect_nature("D.jpeg")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
#
# Top-5 Predictions:
#
# geyser : 33.84%
# barn : 26.77%
# beacon : 9.53%
# alp : 7.29%
# church : 4.34%
#
# Detected Image Nature:
#
# Rocky

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from PIL import Image

# Load pretrained AI model
model = ResNet50(weights="imagenet")

# Nature categories
nature_keywords = {
    "Rocky": ["rock","mountain","cliff","alp","ridge"],
    "Water": ["sea","ocean","lake","river","lakeside","waterfall"],
    "Forest": ["forest","wood","tree","rainforest","pine"],
    "Grassland": ["meadow","field","pasture","prairie","park","lawn"],
    "Sandy": ["sand","beach","sandbar","seashore"],
    "Desert": ["desert","dune"],
    "Snow": ["snow","ice","glacier"],
    "Urban": ["building","street","city","tower","skyscraper"],
    "Storm": ["lightning","storm","thunderstorm","cloud"],
    "Volcano": ["volcano","crater","lava","eruption"],
    "Fire": ["fire","flame","smoke","burning","blaze"]
}

# Disaster prediction rules
def detect_disaster(natures):

    disasters = []

    if "Rocky" in natures and "Water" in natures:
        disasters.append("Landslide Risk")

    if "Snow" in natures and "Rocky" in natures:
        disasters.append("Avalanche Risk")

    if "Water" in natures:
        disasters.append("Flood Risk")

    if "Forest" in natures and "Fire" in natures:
        disasters.append("Forest Fire Risk")

    if "Grassland" in natures:
        disasters.append("Soil Erosion Risk")

    if "Sandy" in natures or "Desert" in natures:
        disasters.append("Desertification Risk")

    if "Storm" in natures:
        disasters.append("Lightning / Thunderstorm Risk")

    if "Volcano" in natures:
        disasters.append("Volcanic Eruption Risk")

    return list(set(disasters))


def detect_nature(image_path):

    try:

        img = Image.open(image_path).convert("RGB")

        plt.imshow(img)
        plt.axis("off")
        plt.title("Input Image")
        plt.show()

        img_resized = img.resize((224,224))
        img_array = np.array(img_resized)

        img_array = np.expand_dims(img_array, axis=0)
        img_array = preprocess_input(img_array)

        preds = model.predict(img_array, verbose=0)
        results = decode_predictions(preds, top=5)[0]

        print("\nDetected Objects:\n")

        labels = []
        confidences = {}

        for obj in results:
            label = obj[1].lower()
            confidence = obj[2] * 100
            labels.append(label)
            confidences[label] = confidence

            print(f"{label} : {confidence:.2f}%")

        print("\nDetected Nature:\n")

        detected_nature = set()

        for nature, keywords in nature_keywords.items():
            for label in labels:
                if any(key in label for key in keywords):
                    detected_nature.add(nature)

        if detected_nature:
            print(", ".join(detected_nature))
        else:
            print("Nature not clearly detected")

        disasters = detect_disaster(detected_nature)

        print("\nNatural Disaster Risk Analysis:\n")

        if disasters:
            confidence = max(confidences.values())
            for d in disasters:
                print(f"⚠ {d} (Confidence ~ {confidence:.2f}%)")
        else:
            print("No major disaster risk detected")

    except FileNotFoundError:
        print("Image file not found.")
    except Exception as e:
        print("Error:", e)


# Run program
detect_nature("DAN.jpeg")
# Out:
# Detected Objects:
#
# quill : 45.84%
# solar_dish : 9.42%
# volcano : 4.17%
# crane : 3.94%
# submarine : 3.57%
#
# Detected Nature:
#
# Volcano
#
# Natural Disaster Risk Analysis:
#
# ⚠ Volcanic Eruption Risk (Confidence ~ 45.84%)

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from PIL import Image

# Load pretrained AI model
model = ResNet50(weights="imagenet")

# Terrain categories
nature_keywords = {
    "Rocky": ["rock","mountain","cliff","alp","ridge","valley"],
    "Water": ["sea","ocean","lake","river","lakeside","waterfall","water"],
    "Forest": ["forest","wood","tree","rainforest","pine"],
    "Grassland": ["meadow","field","pasture","prairie","park","lawn"],
    "Sandy": ["sand","beach","sandbar","seashore"],
    "Desert": ["desert","dune"],
    "Snow": ["snow","ice","glacier"],
    "Storm": ["lightning","storm","thunderstorm","cloud"]
}

# Disaster prediction
def detect_disaster(nature_percent):
    risks = {}

    rocky = nature_percent.get("Rocky",0)
    water = nature_percent.get("Water",0)
    forest = nature_percent.get("Forest",0)
    snow = nature_percent.get("Snow",0)
    sandy = nature_percent.get("Sandy",0)
    storm = nature_percent.get("Storm",0)

    if rocky > 20 and water > 20:
        risks["Landslide"] = (rocky + water)/2
    if snow > 20 and rocky > 20:
        risks["Avalanche"] = (snow + rocky)/2
    if water > 30:
        risks["Flood"] = water
    if forest > 30:
        risks["Wildfire"] = forest * 0.6
    if sandy > 30:
        risks["Desertification"] = sandy
    if storm > 20:
        risks["Thunderstorm"] = storm

    # Normalize risks to percentages
    total_risk = sum(risks.values())
    if total_risk > 0:
        for r in risks:
            risks[r] = (risks[r]/total_risk)*100

    return risks

# Recommendations
def recommend_action(risks):
    suggestions = []
    for r in risks:
        if r == "Landslide":
            suggestions.append("Install slope stabilization")
        if r == "Flood":
            suggestions.append("Improve drainage system")
        if r == "Avalanche":
            suggestions.append("Install avalanche barriers")
        if r == "Wildfire":
            suggestions.append("Create firebreak zones")
        if r == "Desertification":
            suggestions.append("Increase vegetation cover")
        if r == "Thunderstorm":
            suggestions.append("Use lightning protection")
    return suggestions

def detect_nature(image_path):
    img = Image.open(image_path).convert("RGB")

    plt.imshow(img)
    plt.axis("off")
    plt.title("Input Image")
    plt.show()

    img = img.resize((224,224))
    img_array = np.array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    preds = model.predict(img_array)
    results = decode_predictions(preds, top=5)[0]

    labels = []
    confidences = {}

    print("\nDetected Objects\n")
    for r in results:
        label = r[1].lower()
        conf = r[2]*100
        labels.append(label)
        confidences[label] = conf
        print(label,"-",round(conf,2),"%")

    # Terrain scoring
    nature_scores = {}
    for nature,keywords in nature_keywords.items():
        score = 0
        for label in labels:
            if any(k in label for k in keywords):
                score += confidences[label]
        if score>0:
            nature_scores[nature] = score

    total = sum(nature_scores.values())
    nature_percent = {}
    print("\nTerrain Percentage Analysis\n")
    if total == 0:
        print("Could not determine terrain")
        return
    for n,v in nature_scores.items():
        percent = (v/total)*100
        nature_percent[n] = percent
        print(n,":",round(percent,2),"%")

    # Disaster prediction
    risks = detect_disaster(nature_percent)
    print("\nDisaster Probability\n")
    for r,p in risks.items():
        print(r,"Risk:",round(p,2),"%")

    # Visualization
    if risks:
        plt.figure(figsize=(6,4))
        plt.bar(risks.keys(), risks.values(), color="orange")
        plt.ylabel("Risk Probability (%)")
        plt.title("Disaster Risk Analysis")
        plt.show()

    # Recommendations
    suggestions = recommend_action(risks)
    print("\nRecommended Actions\n")
    for s in suggestions:
        print("-",s)

# Run program
detect_nature("AWSED.jpeg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Detected Objects
#
# alp - 69.22 %
# snowplow - 10.53 %
# television - 6.05 %
# ice_bear - 3.28 %
# brown_bear - 2.67 %
#
# Terrain Percentage Analysis
#
# Rocky : 83.37 %
# Snow : 16.63 %
#
# Disaster Probability
#
#
# Recommended Actions

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from PIL import Image

# Load pretrained AI model
model = ResNet50(weights="imagenet")

# Terrain categories
nature_keywords = {
    "Rocky": ["rock","mountain","cliff","alp","ridge","valley"],
    "Water": ["sea","ocean","lake","river","lakeside","waterfall","water"],
    "Forest": ["forest","wood","tree","rainforest","pine"],
    "Grassland": ["meadow","field","pasture","prairie","park","lawn"],
    "Sandy": ["sand","beach","sandbar","seashore"],
    "Desert": ["desert","dune"],
    "Snow": ["snow","ice","glacier"],
    "Storm": ["lightning","storm","thunderstorm","cloud"]
}

# Disaster prediction
def detect_disaster(nature_percent):
    risks = {}

    rocky = nature_percent.get("Rocky",0)
    water = nature_percent.get("Water",0)
    forest = nature_percent.get("Forest",0)
    snow = nature_percent.get("Snow",0)
    sandy = nature_percent.get("Sandy",0)
    storm = nature_percent.get("Storm",0)

    if rocky > 20 and water > 20:
        risks["Landslide"] = (rocky + water)/2
    if snow > 20 and rocky > 20:
        risks["Avalanche"] = (snow + rocky)/2
    if water > 30:
        risks["Flood"] = water
    if forest > 30:
        risks["Wildfire"] = forest * 0.6
    if sandy > 30:
        risks["Desertification"] = sandy
    if storm > 20:
        risks["Thunderstorm"] = storm

    # Normalize risks to percentages
    total_risk = sum(risks.values())
    if total_risk > 0:
        for r in risks:
            risks[r] = (risks[r]/total_risk)*100

    return risks

# Recommendations
def recommend_action(risks):
    suggestions = []
    for r in risks:
        if r == "Landslide":
            suggestions.append("Install slope stabilization")
        if r == "Flood":
            suggestions.append("Improve drainage system")
        if r == "Avalanche":
            suggestions.append("Install avalanche barriers")
        if r == "Wildfire":
            suggestions.append("Create firebreak zones")
        if r == "Desertification":
            suggestions.append("Increase vegetation cover")
        if r == "Thunderstorm":
            suggestions.append("Use lightning protection")
    return suggestions

def detect_nature(image_path):
    img = Image.open(image_path).convert("RGB")

    plt.imshow(img)
    plt.axis("off")
    plt.title("Input Image")
    plt.show()

    img = img.resize((224,224))
    img_array = np.array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    preds = model.predict(img_array)
    results = decode_predictions(preds, top=5)[0]

    labels = []
    confidences = {}

    print("\nDetected Objects\n")
    for r in results:
        label = r[1].lower()
        conf = r[2]*100
        labels.append(label)
        confidences[label] = conf
        print(label,"-",round(conf,2),"%")

    # Terrain scoring
    nature_scores = {}
    for nature,keywords in nature_keywords.items():
        score = 0
        for label in labels:
            if any(k in label for k in keywords):
                score += confidences[label]
        if score>0:
            nature_scores[nature] = score

    total = sum(nature_scores.values())
    nature_percent = {}
    print("\nTerrain Percentage Analysis\n")
    if total == 0:
        print("Could not determine terrain")
        return
    for n,v in nature_scores.items():
        percent = (v/total)*100
        nature_percent[n] = percent
        print(n,":",round(percent,2),"%")

    # Disaster prediction
    risks = detect_disaster(nature_percent)
    print("\nDisaster Probability\n")
    if risks:
        for r,p in risks.items():
            print(r,"Risk:",round(p,2),"%")
    else:
        print("No major disaster risk detected")

    # Visualization
    if risks:
        plt.figure(figsize=(6,4))
        plt.bar(risks.keys(), risks.values(), color="orange")
        plt.ylabel("Risk Probability (%)")
        plt.title("Disaster Risk Analysis")
        plt.show()

    # Recommendations
    print("\nRecommended Actions\n")
    suggestions = recommend_action(risks)
    if suggestions:
        for s in suggestions:
            print("-",s)
    else:
        print("No specific actions recommended")

# Run program
detect_nature("SANDY.jpeg")
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001E9EDA5C0E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#
# Detected Objects
#
# cliff_dwelling - 42.1 %
# cliff - 23.84 %
# dough - 12.56 %
# face_powder - 8.16 %
# meerkat - 2.08 %
#
# Terrain Percentage Analysis
#
# Rocky : 100.0 %
#
# Disaster Probability
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from PIL import Image

# Load pretrained AI model
model = ResNet50(weights="imagenet")

# Terrain dictionary
nature_keywords = {
    "Rocky": ["rock","mountain","cliff","ridge","alp","valley"],
    "Water": ["sea","ocean","lake","river","lakeside","waterfall","water"],
    "Forest": ["forest","wood","tree","rainforest","pine"],
    "Grassland": ["meadow","field","pasture","prairie","park","lawn"],
    "Sandy": ["sand","beach","sandbar","seashore"],
    "Desert": ["desert","dune"],
    "Snow": ["snow","ice","glacier"],
    "Storm": ["storm","thunderstorm","lightning","cloud"]
}

# Disaster prediction model
def detect_disaster(nature_percent):

    risks = {}

    rocky = nature_percent.get("Rocky",0)
    water = nature_percent.get("Water",0)
    forest = nature_percent.get("Forest",0)
    snow = nature_percent.get("Snow",0)
    sandy = nature_percent.get("Sandy",0)
    storm = nature_percent.get("Storm",0)

    # simple probability model
    if rocky > 10 and water > 10:
        risks["Landslide"] = (rocky + water)/2

    if snow > 10 and rocky > 10:
        risks["Avalanche"] = (snow + rocky)/2

    if water > 20:
        risks["Flood"] = water

    if forest > 20:
        risks["Wildfire"] = forest * 0.7

    if sandy > 20:
        risks["Desertification"] = sandy

    if storm > 10:
        risks["Thunderstorm"] = storm

    return risks


# Recommendation system
def recommend_action(risks):

    suggestions = []

    for r in risks:

        if r == "Landslide":
            suggestions.append("Install slope stabilization systems")

        if r == "Flood":
            suggestions.append("Improve drainage systems")

        if r == "Avalanche":
            suggestions.append("Install avalanche barriers")

        if r == "Wildfire":
            suggestions.append("Create firebreak zones")

        if r == "Desertification":
            suggestions.append("Increase vegetation cover")

        if r == "Thunderstorm":
            suggestions.append("Use lightning protection")

    return suggestions


def detect_nature(image_path):

    img = Image.open(image_path).convert("RGB")

    plt.imshow(img)
    plt.axis("off")
    plt.title("Input Image")
    plt.show()

    img = img.resize((224,224))
    img_array = np.array(img)

    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    preds = model.predict(img_array)
    results = decode_predictions(preds, top=5)[0]

    labels = []
    confidences = {}

    print("\nDetected Objects\n")

    for r in results:

        label = r[1].lower()
        conf = r[2]*100

        labels.append(label)
        confidences[label] = conf

        print(label,"-",round(conf,2),"%")

    # Terrain scoring
    nature_scores = {}

    for nature,keywords in nature_keywords.items():

        score = 0

        for label in labels:

            if any(k in label for k in keywords):
                score += confidences[label]

        if score>0:
            nature_scores[nature] = score

    total = sum(nature_scores.values())

    nature_percent = {}

    print("\nTerrain Percentage Analysis\n")

    if total == 0:
        print("Terrain could not be determined")
        return

    for n,v in nature_scores.items():

        percent = (v/total)*100
        nature_percent[n] = percent

        print(n,":",round(percent,2),"%")

    # Disaster prediction
    risks = detect_disaster(nature_percent)

    print("\nDisaster Probability\n")

    if not risks:
        print("No major disaster risk detected")
    else:
        for r,p in risks.items():
            print(r,"Risk:",round(p,2),"%")

    # Visualization
    if risks:

        plt.figure(figsize=(6,4))
        plt.bar(risks.keys(), risks.values(), color="red")
        plt.ylabel("Risk Probability (%)")
        plt.title("Disaster Risk Analysis")
        plt.show()

    # Recommendations
    suggestions = recommend_action(risks)

    print("\nRecommended Actions\n")

    if not suggestions:
        print("No action required")
    else:
        for s in suggestions:
            print("-",s)


# Run program
detect_nature("SANDY.jpeg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Detected Objects
#
# cliff_dwelling - 42.1 %
# cliff - 23.84 %
# dough - 12.56 %
# face_powder - 8.16 %
# meerkat - 2.08 %
#
# Terrain Percentage Analysis
#
# Rocky : 100.0 %
#
# Disaster Probability
#
# No major disaster risk detected
#
# Recommended Actions
#
# No action required

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from PIL import Image

# Load pretrained AI model
model = ResNet50(weights="imagenet")

# Terrain dictionary
nature_keywords = {
    "Rocky": ["rock","mountain","cliff","ridge","alp","valley"],
    "Water": ["sea","ocean","lake","river","lakeside","waterfall","water"],
    "Forest": ["forest","wood","tree","rainforest","pine"],
    "Grassland": ["meadow","field","pasture","prairie","park","lawn"],
    "Sandy": ["sand","beach","sandbar","seashore"],
    "Desert": ["desert","dune"],
    "Snow": ["snow","ice","glacier"],
    "Storm": ["storm","thunderstorm","lightning","cloud","tornado","cyclone","hurricane"]
}

# Disaster prediction model
def detect_disaster(nature_percent):

    risks = {}

    rocky = nature_percent.get("Rocky",0)
    water = nature_percent.get("Water",0)
    forest = nature_percent.get("Forest",0)
    snow = nature_percent.get("Snow",0)
    sandy = nature_percent.get("Sandy",0)
    storm = nature_percent.get("Storm",0)

    # simple probability model
    if rocky > 10 and water > 10:
        risks["Landslide"] = (rocky + water)/2

    if snow > 10 and rocky > 10:
        risks["Avalanche"] = (snow + rocky)/2

    if water > 20:
        risks["Flood"] = water

    if forest > 20:
        risks["Wildfire"] = forest * 0.7

    if sandy > 20:
        risks["Desertification"] = sandy

    if storm > 10:
        risks["Thunderstorm"] = storm

    return risks


# Recommendation system
def recommend_action(risks):

    suggestions = []

    for r in risks:

        if r == "Landslide":
            suggestions.append("Install slope stabilization systems")

        if r == "Flood":
            suggestions.append("Improve drainage systems")

        if r == "Avalanche":
            suggestions.append("Install avalanche barriers")

        if r == "Wildfire":
            suggestions.append("Create firebreak zones")

        if r == "Desertification":
            suggestions.append("Increase vegetation cover")

        if r == "Thunderstorm":
            suggestions.append("Use lightning protection")

    return suggestions


def detect_nature(image_path):

    img = Image.open(image_path).convert("RGB")

    plt.imshow(img)
    plt.axis("off")
    plt.title("Input Image")
    plt.show()

    img = img.resize((224,224))
    img_array = np.array(img)

    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    preds = model.predict(img_array)
    results = decode_predictions(preds, top=5)[0]

    labels = []
    confidences = {}

    print("\nDetected Objects\n")

    for r in results:

        label = r[1].lower()
        conf = r[2]*100

        labels.append(label)
        confidences[label] = conf

        print(label,"-",round(conf,2),"%")

    # Terrain scoring
    nature_scores = {}

    for nature,keywords in nature_keywords.items():

        score = 0

        for label in labels:

            if any(k in label for k in keywords):
                score += confidences[label]

        if score>0:
            nature_scores[nature] = score

    total = sum(nature_scores.values())

    nature_percent = {}

    print("\nTerrain Percentage Analysis\n")

    if total == 0:
        print("Terrain could not be determined")
        return

    for n,v in nature_scores.items():

        percent = (v/total)*100
        nature_percent[n] = percent

        print(n,":",round(percent,2),"%")

    # Disaster prediction
    risks = detect_disaster(nature_percent)

    print("\nDisaster Probability\n")

    if not risks:
        print("No major disaster risk detected")
    else:
        for r,p in risks.items():
            print(r,"Risk:",round(p,2),"%")

    # Visualization
    if risks:

        plt.figure(figsize=(6,4))
        plt.bar(risks.keys(), risks.values(), color="red")
        plt.ylabel("Risk Probability (%)")
        plt.title("Disaster Risk Analysis")
        plt.show()

    # Recommendations
    suggestions = recommend_action(risks)

    print("\nRecommended Actions\n")

    if not suggestions:
        print("No action required")
    else:
        for s in suggestions:
            print("-",s)


# Run program
detect_nature("DAN.jpeg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Detected Objects
#
# quill - 45.84 %
# solar_dish - 9.42 %
# volcano - 4.17 %
# crane - 3.94 %
# submarine - 3.57 %
#
# Terrain Percentage Analysis
#
# Terrain could not be determined

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from PIL import Image

# Load AI model
model = ResNet50(weights="imagenet")

# Terrain / weather keywords
nature_keywords = {
    "Rocky": ["rock","mountain","cliff","alp","ridge","valley"],
    "Water": ["sea","ocean","lake","river","lakeside","waterfall","water"],
    "Forest": ["forest","wood","tree","rainforest","pine"],
    "Grassland": ["meadow","field","pasture","prairie","park","lawn"],
    "Sandy": ["sand","beach","sandbar","seashore"],
    "Desert": ["desert","dune"],
    "Snow": ["snow","ice","glacier"],
    "Storm": ["storm","cloud","thundercloud","tornado","cyclone","hurricane"],
    "Fire": ["fire","volcano","lava","eruption"]

}

# Disaster detection
def detect_disaster(nature_percent):
    risks = {}

    if "Storm" in nature_percent:
        risks["Tornado / Thunderstorm"] = nature_percent["Storm"]

    if "Water" in nature_percent:
        risks["Flood"] = nature_percent["Water"]

    if "Rocky" in nature_percent and "Water" in nature_percent:
        risks["Landslide"] = (nature_percent["Rocky"] + nature_percent["Water"]) / 2

    if "Snow" in nature_percent and "Rocky" in nature_percent:
        risks["Avalanche"] = (nature_percent["Snow"] + nature_percent["Rocky"]) / 2

    if nature_percent.get("Fire", 0) > 20:
        risks["Volcanic Eruption"] = nature_percent["Fire"]

    return risks


# Safety recommendations
def recommend_actions(risks):

    actions = []

    for r in risks:

        if r == "Tornado / Thunderstorm":
            actions.extend([
                "Seek shelter immediately",
                "Avoid open areas",
                "Monitor weather alerts"
            ])

        if r == "Flood":
            actions.extend([
                "Move to higher ground",
                "Avoid flooded roads"
            ])

        if r == "Landslide":
            actions.extend([
                "Stay away from steep slopes",
                "Evacuate unstable terrain"
            ])

        if r == "Avalanche":
            actions.extend([
                "Avoid snowy mountain slopes",
                "Follow avalanche warnings"
            ])

    return actions


def detect_nature(image_path):

    img = Image.open(image_path).convert("RGB")

    plt.imshow(img)
    plt.axis("off")
    plt.title("Input Image")
    plt.show()

    img = img.resize((224,224))
    img_array = np.array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    preds = model.predict(img_array)
    results = decode_predictions(preds, top=5)[0]

    labels = []

    print("\nDetected Objects\n")

    for r in results:
        label = r[1].lower()
        conf = r[2]*100
        labels.append(label)
        print(label,"-",round(conf,2),"%")

    # Detect terrain types
    detected_nature = set()

    for nature,keywords in nature_keywords.items():
        for label in labels:
            if any(k in label for k in keywords):
                detected_nature.add(nature)

    print("\nDetected Terrain / Weather\n")
    print(detected_nature)

    # Disaster risk
    risks = detect_disaster(detected_nature)

    print("\nDisaster Risk\n")

    if not risks:
        print("No major disaster detected")
    else:
        for r in risks:
            print(r)

    # Recommended actions
    actions = recommend_actions(risks)

    print("\nRecommended Actions\n")

    if not actions:
        print("No action required")
    else:
        for a in actions:
            print("-",a)


# Run
detect_nature("FOREST.jpeg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#
# Detected Objects
#
# fire_screen - 50.92 %
# volcano - 45.86 %
# stove - 2.77 %
# caldron - 0.2 %
# dutch_oven - 0.19 %
#
# Detected Terrain / Weather
#
# {'Fire'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 142
#     138             print("-",a)
#     141 # Run
# --> 142 detect_nature("FOREST.jpeg")
#
# Cell In[14], line 119, in detect_nature(image_path)
#     116 print(detected_nature)
#     118 # Disaster risk
# --> 119 risks = detect_disaster(detected_nature)
#     121 print("\nDisaster Risk\n")
#     123 if not risks:
#
# Cell In[14], line 39, in detect_disaster(nature_percent)
#      36 if "Snow" in nature_percent and "Rocky" in nature_percent:
#      37     risks["Avalanche"] = (nature_percent["Snow"] + nature_percent["Rocky"]) / 2
# ---> 39 if nature_percent.get("Fire", 0) > 20:
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from PIL import Image

# Load AI model
model = ResNet50(weights="imagenet")

# Terrain / weather keywords
nature_keywords = {
    "Rocky": ["rock","mountain","cliff","alp","ridge","valley"],
    "Water": ["sea","ocean","lake","river","lakeside","waterfall","water"],
    "Forest": ["forest","wood","tree","rainforest","pine"],
    "Grassland": ["meadow","field","pasture","prairie","park","lawn"],
    "Sandy": ["sand","beach","sandbar","seashore"],
    "Desert": ["desert","dune"],
    "Snow": ["snow","ice","glacier"],
    "Storm": ["storm","cloud","thundercloud","tornado","cyclone","hurricane"],
    "Fire": ["fire","volcano","lava","eruption"],
    "Agriculture": ["hay","barn","rapeseed","field","crop","farm"]
}

# Disaster detection
def detect_disaster(detected_nature):
    risks = []

    if "Storm" in detected_nature:
        risks.append("Tornado / Thunderstorm")

    if "Water" in detected_nature:
        risks.append("Flood")

    if "Rocky" in detected_nature and "Water" in detected_nature:
        risks.append("Landslide")

    if "Snow" in detected_nature and "Rocky" in detected_nature:
        risks.append("Avalanche")

    if "Fire" in detected_nature:
        risks.append("Volcanic Eruption")

    return risks


# Safety recommendations
def recommend_actions(risks):

    actions = []

    for r in risks:

        if r == "Tornado / Thunderstorm":
            actions.extend([
                "Seek shelter immediately",
                "Avoid open areas",
                "Monitor weather alerts"
            ])

        if r == "Flood":
            actions.extend([
                "Move to higher ground",
                "Avoid flooded roads"
            ])

        if r == "Landslide":
            actions.extend([
                "Stay away from steep slopes",
                "Evacuate unstable terrain"
            ])

        if r == "Avalanche":
            actions.extend([
                "Avoid snowy mountain slopes",
                "Follow avalanche warnings"
            ])

        if r == "Volcanic Eruption":
            actions.extend([
                "Prepare evacuation routes",
                "Keep emergency supplies ready",
                "Monitor volcanic activity alerts",
                "Avoid valleys and low-lying areas near volcanoes"
            ])

    return actions


def detect_nature(image_path):

    img = Image.open(image_path).convert("RGB")

    plt.imshow(img)
    plt.axis("off")
    plt.title("Input Image")
    plt.show()

    img = img.resize((224,224))
    img_array = np.array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    preds = model.predict(img_array)
    results = decode_predictions(preds, top=5)[0]

    labels = []

    print("\nDetected Objects\n")

    for r in results:
        label = r[1].lower()
        conf = r[2]*100
        labels.append(label)
        print(label,"-",round(conf,2),"%")

    # Detect terrain types
    detected_nature = set()

    for nature,keywords in nature_keywords.items():
        for label in labels:
            if any(k in label for k in keywords):
                detected_nature.add(nature)

    print("\nDetected Terrain / Weather\n")
    print(detected_nature)

    # Disaster risk
    risks = detect_disaster(detected_nature)

    print("\nDisaster Risk\n")

    if not risks:
        print("No major disaster detected")
    else:
        for r in risks:
            print(r)

    # Recommended actions
    actions = recommend_actions(risks)

    print("\nRecommended Actions\n")

    if not actions:
        print("No action required")
    else:
        for a in actions:
            print("-",a)


# Run
detect_nature("Today 1.jpeg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#
# Detected Objects
#
# megalith - 28.98 %
# alp - 11.87 %
# stone_wall - 8.09 %
# worm_fence - 6.56 %
# valley - 6.52 %
#
# Detected Terrain / Weather
#
# {'Rocky'}
#
# Disaster Risk
#
# No major disaster detected
#
# Recommended Actions
#
# No action required
